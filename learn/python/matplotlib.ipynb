# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([1, 2, 3], [2, 4, 6])

# %%
x = [0, 1, 2, 3]
y = [0, 2, 4, 6]

plt.plot(x, y)
plt.title('This is matplotlib', fontdict={'fontname': 'Courier New', 'fontsize': 16})
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xticks([0, 5, 10, 15])
plt.yticks([0, 50, 100, 500])

plt.show()

# %%
x = np.linspace(10, -10, 21)
y = x ** 2

plt.plot(x, y)

# %%
def collatz(x):
    if x % 2:
        x = (3 * x + 1) / 2
    else:
        x = x / 2
    return x

y = np.vectorize(collatz)
y(50)
plt.plot(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/gx/4nk6lw0x6f7d3fldfbxd6p2r0000gn/T/ipykernel_4798/1004356204.py in <module>
#       8 y = np.vectorize(collatz)
#       9 y(50)
# ---> 10 plt.plot(y)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...
