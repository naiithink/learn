# %%
from __future__ import print_function, with_statement
from IPython.display import display, HTML

# %%
script = """
<script type="text/javascript">
    function submit() {
        var q01_a01_01 = document.getElementById("q01_a01_01").value;
        if (q01_a01_01) {
            document.getElementById("gotten").innerHTML = q01_a01_01;
        } else {
            document.getElementById("gotten").innerHTML = "Something went wrong.";
        }
        var run = display(HTML(src + code + got + script));
        IPython.notebook.kernel.execute("print('hello, world')");
    }
</script>
"""

src = """
<h1>01 คอมพิวเตอร์ทำงาน</h1>
จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br />
เมื่อตัวแปร <code>computer_time</code> เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br />
<br />
<b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 785</b><br />
<code>
It is 0 days 13 hours and 5 minutes.
</code>
<br />
อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br />
<br />
<b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 1678</b><br />
<code>
It is 1 days 3 hours and 58 minutes.
</code>
<br />
อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที<br />
"""

code = """
<div class="highlight">
<pre>
#include<stdio.h>
void main() {
    int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
<textarea id="q01_a01_01" rows="7" cols="97">
Your code here...
</textarea>
}
</pre>
</div>
<input type="button" onclick="submit()" value="Submit" />
"""

got = """
<p id="gotten"></p>
"""

display(HTML(src + code + got + script))
# Out:
# <h1>01 คอมพิวเตอร์ทำงาน</h1>
# จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br />
# เมื่อตัวแปร <code>computer_time</code> เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 785</b><br />
# <code>
# It is 0 days 13 hours and 5 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 1678</b><br />
# <code>
# It is 1 days 3 hours and 58 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที<br />
#
# <div class="highlight">
# <pre>
# #include<stdio.h>
# void main() {
#     int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
# <textarea id="q01_a01_01" rows="7" cols="97">
# Your code here...
# </textarea>
# }
# </pre>
# </div>
# <input type="button" onclick="submit()" value="Submit" />
#
# <p id="gotten"></p>
#
# <script type="text/javascript">
#     function submit() {
#         var q01_a01_01 = document.getElementById("q01_a01_01").value;
#         if (q01_a01_01) {
#             document.getElementById("gotten").innerHTML = q01_a01_01;
#         } else {
#             document.getElementById("gotten").innerHTML = "Something went wrong.";
#         }
#         var run = display(HTML(src + code + got + script));
#         IPython.notebook.kernel.execute("print('hello, world')");
#     }
# </script>

# %%
# from IPython.display import display, Code, HTML
# from pygments.styles import get_style_by_name
# from pygments import highlight
# from pygments.lexers import CLexer
# from pygments.formatters import HtmlFormatter
# import ipywidgets as widgets
# from ipywidgets import interact

# %%
# q01_01 = """
# <h1>01 คอมพิวเตอร์ทำงาน</h1>
# จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br />
# เมื่อตัวแปร <code>computer_time</code> เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 785</b><br />
# <code>
# It is 0 days 13 hours and 5 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 1678</b><br />
# <code>
# It is 1 days 3 hours and 58 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที<br />
# <hr style="height:2px;border-width:0;color:gray;background-color:gray" />
# """
# 
# q01_src01 = """
# #include<stdio.h>
# void main() {
#    int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
# """
# 
# q01_src02 = """
# <textarea id="q01" rows="7" cols="97">
# </textarea>
# """
# 
# q01_src03 = """
# }
# """
# 
# display(
#     HTML(q01_01),
#     HTML(highlight(q01_src01, CLexer(platformhilighting=True), HtmlFormatter(full=True, noclasses=True, style="arduino", nobackground=True))),
#     HTML(q01_src02),
#     HTML(highlight(q01_src03, CLexer(platformhilighting=True), HtmlFormatter(full=True, noclasses=True, style="arduino", nobackground=True)))
# )

# paraiso-dark, arduino, solarized-dark, solarized-light, dracula

# %%
# %%html
# <script>
#    var ans01_01 = document.getElementById("q01_01").value;
#    
# </script>
# <h1>01 คอมพิวเตอร์ทำงาน</h1>
# จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br />
# เมื่อตัวแปร <code>computer_time</code> เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 785</b><br />
# <code>
# It is 0 days 13 hours and 5 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 1678</b><br />
# <code>
# It is 1 days 3 hours and 58 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที<br />
# <hr style="height:2px;border-width:0;color:gray;background-color:gray" />
# <div class="highlight">
# <pre>
# #include<stdio.h>
# void main() {
#    int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
# <textarea id="q01-01" rows="7" cols="97">
# </textarea>
# }
# </pre>
# </div>

# %%
# # from IPython.core import display
# from IPython.lib import clipboard
# from IPython.display import display, HTML
# 
# src = """
# <script type="text/javascript">
#     document.getElementById("demo").innerHTML = "clip:";
#     function myFunction() {
#         var copyText = document.getElementById("myInput");
# 
#         copyText.select();
#         copyText.setSelectRange(0, 99);
# 
#         navigator.clipboard.writeText(copyText.value);
#     }
# </script>
# <h1>hello</h1>
# <input type="text" value="hello, world.." id="myInput" />
# <button onclick="myFunction()">Copy text</button>
# <div id="demo"></div>
# """
# 
# display(HTML(src))
