# %%
from IPython.display import display, Code, HTML
from pygments.styles import get_style_by_name
from pygments import highlight
from pygments.lexers import CLexer
from pygments.formatters import HtmlFormatter
import ipywidgets as widgets
from ipywidgets import interact

# %% [markdown]
# ## 01 คอมพิวเตอร์ทำงาน
#
# ---
#
# **คอมพิวเตอร์ทำงาน**
#
# จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)
#
# เมื่อตัวแปร `computer_time` เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน
#
# ### ตัวอย่างผลลัพธ์เมื่อ `computer_time` มีค่า 785
#
# ```
# It is 0 days 13 hours and 5 minutes.
# ```
#
# อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที
#
# ### ตัวอย่างผลลัพธ์เมื่อ `computer_time` มีค่า 1678
#
# ```
# It is 1 days 3 hours and 58 minutes.
# ```
#
# อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที
#
# ```c
# #include<stdio.h>
# void main() {
#    int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
# /*
#  *
#  *
#  *
#  *
#  *
#  *
#  8 */
# }
# ```

# %%
lab01 = """
<h1>01 คอมพิวเตอร์ทำงาน</h1>
จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br />
เมื่อตัวแปร <code>computer_time</code> เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br />
<br />
<b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 785</b><br />
<code>
It is 0 days 13 hours and 5 minutes.
</code>
<br />
อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br />
<br />
<b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 1678</b><br />
<code>
It is 1 days 3 hours and 58 minutes.
</code>
<br />
อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที<br />
<pre>
<code>
#include<stdio.h>
void main() {
   int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
<textarea id="q01" rows="7" cols="97">
</textarea>
}
</code>
</pre>
"""

ans1 = """
<textarea id="q01" rows="7" cols="97">
</textarea>
"""

code1 = """
#include<stdio.h>
void main() {
   int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
"""

code2 = """}"""

display(
    HTML(data=lab01),
    HTML(highlight(lab01, CLexer(platformhilighting=True), HtmlFormatter(full=True, style="arduino", nobackground=True))),
    HTML(ans1),
    HTML(highlight(code2, CLexer(platformhilighting=True), HtmlFormatter(full=True, style="arduino", nobackground=True))),
)

# paraiso-dark, arduino, solarized-dark, solarized-light, dracula
# Out:
# <h1>01 คอมพิวเตอร์ทำงาน</h1>
# จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br />
# เมื่อตัวแปร <code>computer_time</code> เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 785</b><br />
# <code>
# It is 0 days 13 hours and 5 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br />
# <br />
# <b>ตัวอย่างผลลัพธ์เมื่อ <code>computer_time</code> มีค่า 1678</b><br />
# <code>
# It is 1 days 3 hours and 58 minutes.
# </code>
# <br />
# อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที<br />
# <pre>
# <code>
# #include<stdio.h>
# void main() {
#    int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
# <textarea id="q01" rows="7" cols="97">
# </textarea>
# }
# </code>
# </pre>
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body .c { color: #95a5a6 } /* Comment */
# body .err { color: #a61717 } /* Error */
# body .k { color: #728E00 } /* Keyword */
# body .n { color: #434f54 } /* Name */
# body .o { color: #728E00 } /* Operator */
# body .ch { color: #95a5a6 } /* Comment.Hashbang */
# body .cm { color: #95a5a6 } /* Comment.Multiline */
# body .cp { color: #728E00 } /* Comment.Preproc */
# body .cpf { color: #95a5a6 } /* Comment.PreprocFile */
# body .c1 { color: #95a5a6 } /* Comment.Single */
# body .cs { color: #95a5a6 } /* Comment.Special */
# body .kc { color: #00979D } /* Keyword.Constant */
# body .kd { color: #728E00 } /* Keyword.Declaration */
# body .kn { color: #728E00 } /* Keyword.Namespace */
# body .kp { color: #00979D } /* Keyword.Pseudo */
# body .kr { color: #00979D } /* Keyword.Reserved */
# body .kt { color: #00979D } /* Keyword.Type */
# body .m { color: #8A7B52 } /* Literal.Number */
# body .s { color: #7F8C8D } /* Literal.String */
# body .na { color: #434f54 } /* Name.Attribute */
# body .nb { color: #728E00 } /* Name.Builtin */
# body .nc { color: #434f54 } /* Name.Class */
# body .no { color: #434f54 } /* Name.Constant */
# body .nd { color: #434f54 } /* Name.Decorator */
# body .ni { color: #434f54 } /* Name.Entity */
# body .ne { color: #434f54 } /* Name.Exception */
# body .nf { color: #D35400 } /* Name.Function */
# body .nl { color: #434f54 } /* Name.Label */
# body .nn { color: #434f54 } /* Name.Namespace */
# body .nx { color: #728E00 } /* Name.Other */
# body .py { color: #434f54 } /* Name.Property */
# body .nt { color: #434f54 } /* Name.Tag */
# body .nv { color: #434f54 } /* Name.Variable */
# body .ow { color: #728E00 } /* Operator.Word */
# body .mb { color: #8A7B52 } /* Literal.Number.Bin */
# body .mf { color: #8A7B52 } /* Literal.Number.Float */
# body .mh { color: #8A7B52 } /* Literal.Number.Hex */
# body .mi { color: #8A7B52 } /* Literal.Number.Integer */
# body .mo { color: #8A7B52 } /* Literal.Number.Oct */
# body .sa { color: #7F8C8D } /* Literal.String.Affix */
# body .sb { color: #7F8C8D } /* Literal.String.Backtick */
# body .sc { color: #7F8C8D } /* Literal.String.Char */
# body .dl { color: #7F8C8D } /* Literal.String.Delimiter */
# body .sd { color: #7F8C8D } /* Literal.String.Doc */
# body .s2 { color: #7F8C8D } /* Literal.String.Double */
# body .se { color: #7F8C8D } /* Literal.String.Escape */
# body .sh { color: #7F8C8D } /* Literal.String.Heredoc */
# body .si { color: #7F8C8D } /* Literal.String.Interpol */
# body .sx { color: #7F8C8D } /* Literal.String.Other */
# body .sr { color: #7F8C8D } /* Literal.String.Regex */
# body .s1 { color: #7F8C8D } /* Literal.String.Single */
# body .ss { color: #7F8C8D } /* Literal.String.Symbol */
# body .bp { color: #728E00 } /* Name.Builtin.Pseudo */
# body .fm { color: #D35400 } /* Name.Function.Magic */
# body .vc { color: #434f54 } /* Name.Variable.Class */
# body .vg { color: #434f54 } /* Name.Variable.Global */
# body .vi { color: #434f54 } /* Name.Variable.Instance */
# body .vm { color: #434f54 } /* Name.Variable.Magic */
# body .il { color: #8A7B52 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="o">&lt;</span><span class="n">h1</span><span class="o">&gt;</span><span class="mo">01</span><span class="w"> </span><span class="n">คอมพ</span><span class="err">ิ</span><span class="n">วเตอร</span><span class="err">์</span><span class="n">ทำงาน</span><span class="o">&lt;/</span><span class="n">h1</span><span class="o">&gt;</span><span class="w"></span>
# <span class="n">จงเข</span><span class="err">ี</span><span class="n">ยนโปรแกรมเพ</span><span class="err">ื่</span><span class="n">อแสดงผลเวลาท</span><span class="err">ี่</span><span class="n">เคร</span><span class="err">ื่</span><span class="n">องคอมพ</span><span class="err">ิ</span><span class="n">วเตอร</span><span class="err">์</span><span class="n">ทำงานในร</span><span class="err">ู</span><span class="n">ปของจำนวนว</span><span class="err">ั</span><span class="n">น</span><span class="w"> </span><span class="n">ช</span><span class="err">ั่</span><span class="n">วโมง</span><span class="w"> </span><span class="n">และนาท</span><span class="err">ี</span><span class="w"> </span><span class="n">ตามลำด</span><span class="err">ั</span><span class="n">บ</span><span class="w"> </span><span class="p">(</span><span class="n">ไม</span><span class="err">่</span><span class="n">ต</span><span class="err">้</span><span class="n">องคำน</span><span class="err">ึ</span><span class="n">ง</span><span class="p">)</span><span class="o">&lt;</span><span class="n">br</span><span class="w"> </span><span class="o">/&gt;</span><span class="w"></span>
# <span class="n">เม</span><span class="err">ื่</span><span class="n">อต</span><span class="err">ั</span><span class="n">วแปร</span><span class="w"> </span><span class="o">&lt;</span><span class="n">code</span><span class="o">&gt;</span><span class="n">computer_time</span><span class="o">&lt;/</span><span class="n">code</span><span class="o">&gt;</span><span class="w"> </span><span class="n">เก</span><span class="err">็</span><span class="n">บค</span><span class="err">่</span><span class="n">าจำนวนนาท</span><span class="err">ี</span><span class="n">ท</span><span class="err">ี่</span><span class="n">เคร</span><span class="err">ื่</span><span class="n">องคอมพ</span><span class="err">ิ</span><span class="n">วเตอร</span><span class="err">์</span><span class="n">ทำงาน</span><span class="o">&lt;</span><span class="n">br</span><span class="w"> </span><span class="o">/&gt;</span><span class="w"></span>
# <span class="o">&lt;</span><span class="n">br</span><span class="w"> </span><span class="o">/&gt;</span><span class="w"></span>
# <span class="o">&lt;</span><span class="n">b</span><span class="o">&gt;</span><span class="n">ต</span><span class="err">ั</span><span class="n">วอย</span><span class="err">่</span><span class="n">างผลล</span><span class="err">ั</span><span class="n">พธ</span><span class="err">์</span><span class="n">เม</span><span class="err">ื่</span><span class="n">อ</span><span class="w"> </span><span class="o">&lt;</span><span class="n">code</span><span class="o">&gt;</span><span class="n">computer_time</span><span class="o">&lt;/</span><span class="n">code</span><span class="o">&gt;</span><span class="w"> </span><span class="n">ม</span><span class="err">ี</span><span class="n">ค</span><span class="err">่</span><span class="n">า</span><span class="w"> </span><span class="mi">785</span><span class="o">&lt;/</span><span class="n">b</span><span class="o">&gt;&lt;</span><span class="n">br</span><span class="w"> </span><span class="o">/&gt;</span><span class="w"></span>
# <span class="o">&lt;</span><span class="n">code</span><span class="o">&gt;</span><span class="w"></span>
# <span class="n">It</span><span class="w"> </span><span class="n">is</span><span class="w"> </span><span class="mi">0</span><span class="w"> </span><span class="n">days</span><span class="w"> </span><span class="mi">13</span><span class="w"> </span><span class="n">hours</span><span
# <textarea id="q01" rows="7" cols="97">
# </textarea>
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body .c { color: #95a5a6 } /* Comment */
# body .err { color: #a61717 } /* Error */
# body .k { color: #728E00 } /* Keyword */
# body .n { color: #434f54 } /* Name */
# body .o { color: #728E00 } /* Operator */
# body .ch { color: #95a5a6 } /* Comment.Hashbang */
# body .cm { color: #95a5a6 } /* Comment.Multiline */
# body .cp { color: #728E00 } /* Comment.Preproc */
# body .cpf { color: #95a5a6 } /* Comment.PreprocFile */
# body .c1 { color: #95a5a6 } /* Comment.Single */
# body .cs { color: #95a5a6 } /* Comment.Special */
# body .kc { color: #00979D } /* Keyword.Constant */
# body .kd { color: #728E00 } /* Keyword.Declaration */
# body .kn { color: #728E00 } /* Keyword.Namespace */
# body .kp { color: #00979D } /* Keyword.Pseudo */
# body .kr { color: #00979D } /* Keyword.Reserved */
# body .kt { color: #00979D } /* Keyword.Type */
# body .m { color: #8A7B52 } /* Literal.Number */
# body .s { color: #7F8C8D } /* Literal.String */
# body .na { color: #434f54 } /* Name.Attribute */
# body .nb { color: #728E00 } /* Name.Builtin */
# body .nc { color: #434f54 } /* Name.Class */
# body .no { color: #434f54 } /* Name.Constant */
# body .nd { color: #434f54 } /* Name.Decorator */
# body .ni { color: #434f54 } /* Name.Entity */
# body .ne { color: #434f54 } /* Name.Exception */
# body .nf { color: #D35400 } /* Name.Function */
# body .nl { color: #434f54 } /* Name.Label */
# body .nn { color: #434f54 } /* Name.Namespace */
# body .nx { color: #728E00 } /* Name.Other */
# body .py { color: #434f54 } /* Name.Property */
# body .nt { color: #434f54 } /* Name.Tag */
# body .nv { color: #434f54 } /* Name.Variable */
# body .ow { color: #728E00 } /* Operator.Word */
# body .mb { color: #8A7B52 } /* Literal.Number.Bin */
# body .mf { color: #8A7B52 } /* Literal.Number.Float */
# body .mh { color: #8A7B52 } /* Literal.Number.Hex */
# body .mi { color: #8A7B52 } /* Literal.Number.Integer */
# body .mo { color: #8A7B52 } /* Literal.Number.Oct */
# body .sa { color: #7F8C8D } /* Literal.String.Affix */
# body .sb { color: #7F8C8D } /* Literal.String.Backtick */
# body .sc { color: #7F8C8D } /* Literal.String.Char */
# body .dl { color: #7F8C8D } /* Literal.String.Delimiter */
# body .sd { color: #7F8C8D } /* Literal.String.Doc */
# body .s2 { color: #7F8C8D } /* Literal.String.Double */
# body .se { color: #7F8C8D } /* Literal.String.Escape */
# body .sh { color: #7F8C8D } /* Literal.String.Heredoc */
# body .si { color: #7F8C8D } /* Literal.String.Interpol */
# body .sx { color: #7F8C8D } /* Literal.String.Other */
# body .sr { color: #7F8C8D } /* Literal.String.Regex */
# body .s1 { color: #7F8C8D } /* Literal.String.Single */
# body .ss { color: #7F8C8D } /* Literal.String.Symbol */
# body .bp { color: #728E00 } /* Name.Builtin.Pseudo */
# body .fm { color: #D35400 } /* Name.Function.Magic */
# body .vc { color: #434f54 } /* Name.Variable.Class */
# body .vg { color: #434f54 } /* Name.Variable.Global */
# body .vi { color: #434f54 } /* Name.Variable.Instance */
# body .vm { color: #434f54 } /* Name.Variable.Magic */
# body .il { color: #8A7B52 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="p">}</span><span class="w"></span>
# </pre></div>
# </body>
# </html>

# %%
from pygments.styles import get_all_styles
styles = list(get_all_styles())

print(styles)
# Out:
# ['default', 'emacs', 'friendly', 'friendly_grayscale', 'colorful', 'autumn', 'murphy', 'manni', 'material', 'monokai', 'perldoc', 'pastie', 'borland', 'trac', 'native', 'fruity', 'bw', 'vim', 'vs', 'tango', 'rrt', 'xcode', 'igor', 'paraiso-light', 'paraiso-dark', 'lovelace', 'algol', 'algol_nu', 'arduino', 'rainbow_dash', 'abap', 'solarized-dark', 'solarized-light', 'sas', 'stata', 'stata-light', 'stata-dark', 'inkpot', 'zenburn', 'gruvbox-dark', 'gruvbox-light', 'dracula', 'one-dark', 'lilypond']

# %%
# from IPython.core import display
from IPython.display import display, HTML

src = """
<script>
    document.getElementById("demo").innerHTML = 10 + 1;
    function myFunction() {
        var copyText = document.getElementById("myInput");

        copyText.select();
        copyText.setSelectRange(0, 99);

        navigator.clipboard.writeText(copyText.value);
    }
</script>
<h1>hello</h1>
<input type="text" value="hello, world.." id="myInput" />
<button onclick="myFunction()">Copy text</button>
<div id="demo"></div>
"""

display(HTML(src))
# Out:
# <script>
#     document.getElementById("demo").innerHTML = 10 + 1;
#     function myFunction() {
#         var copyText = document.getElementById("myInput");
#
#         copyText.select();
#         copyText.setSelectRange(0, 99);
#
#         navigator.clipboard.writeText(copyText.value);
#     }
# </script>
# <h1>hello</h1>
# <input type="text" value="hello, world.." id="myInput" />
# <button onclick="myFunction()">Copy text</button>
# <div id="demo"></div>
